# %%
import pandas as pd

# %%
df =  pd.read_csv('Scraper-PDF/outputs/master_workbook.csv')

# %%
df
# Out:
#                      company ticker                full_title  Page  \
# 0   Lennox International Inc    LII  report-governance-social    14
# 1   Lennox International Inc    LII  report-governance-social    17
# 2   Lennox International Inc    LII  report-governance-social    38
# 3   Lennox International Inc    LII  report-governance-social    50
# 4   Lennox International Inc    LII  report-governance-social    10
# 5   Lennox International Inc    LII  report-governance-social    10
# 6   Lennox International Inc    LII  report-governance-social    11
# 7   Lennox International Inc    LII  report-governance-social    12
# 8   Lennox International Inc    LII  report-governance-social    14
# 9   Lennox International Inc    LII  report-governance-social     3
# 10  Lennox International Inc    LII  report-governance-social     7
# 11  Lennox International Inc    LII  report-governance-social     9
# 12  Lennox International Inc    LII  report-governance-social    12
# ...

# %%
df['full_text'].iloc[0]
# Out:
# 'LII is committed \nto transitioning all Lennox residential \nand commercial products to low GWP \nrefrigerants by 2025 in line with expected \nregulations. We are evaluating our current  \nenergy usage intensity target (25% reduction by 2024 from a 2014 \nbaseline) to ensure alignment with our emissions reduction target. We actively participate in and work with \nvarious industry associations, sustainability-  \nfocused coalitions, environmental advocates, \nand\tother\tstakeholders\tto\tinfluence\tand \npromote:  \n• Energy\tefficiency\tstandards\tfor\tHVACR\t\nproducts\n• Product\tcertification,\tverification,\tand\t\ntesting\tfor\tproduct\tefficiency\tratings\n• Phaseout of ozone depleting refrigerants\n• Phasedown of high global warming \npotential refrigerants\n• Air quality and emissions standards\n• Tax policy or other government incentives \nthat encourage the purchase and \ninstallation\tof\thigh\tefficiency\tproductsPublic Policy\nEXAMPLES OF LII’S  \nADVOCACY PARTNERS  \n
# ...

# %%
df2 = pd.read_csv('Integrate & upload/integrate-output/integratedtargetdata-January2023.csv')

# %%
df2
# Out:
#                        Company  company press release alias  \
# 0     Lennox International Inc                          NaN
# 1     Lennox International Inc                          NaN
# 2     Lennox International Inc                          NaN
# 3     Lennox International Inc                          NaN
# 4     Lennox International Inc                          NaN
# ..                         ...                          ...
# 671   Lennox International Inc                          NaN
# 672           Carlisle Cos Inc                          NaN
# 673                   AT&T Inc                          NaN
# 674     Schneider National Inc                          NaN
# 675  MGM Resorts International                          NaN
#
#     Member of the S&P500 Member of the Russell 1000 Index Ticker(s)  \
# 0                     no                              yes       LII
# 1                     no                              yes       LII
# ...

# %%
from configparser import ConfigParser

# %%
config = ConfigParser(interpolation=None)
config.read('./Scraper-PDF/crawler.cfg')
# Out:
# ['./Scraper-PDF/crawler.cfg']

# %%
# Number of companies to scrape
num_companies = config['COMPANY']['num_companies']
num_companies
# Out:
# '1'

# %%
config['COMPANY']['num_companies']
# Out:
# '1'
